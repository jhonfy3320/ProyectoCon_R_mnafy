# %%
# Instalar (si no lo tienes) y cargar librerías esenciales
install.packages(c("tidyverse", "GGally"))
library(tidyverse)   # Incluye ggplot2, dplyr, tidyr…
library(GGally)      # Funciones para pair plots

mtcars <- read.csv('/home/jhonfypy/ProyectoCon_R_mnafy/mtcars.csv')
orangeec <- read_csv("/home/jhonfypy/ProyectoCon_R_mnafy/orangeec.csv")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
# Rows: 17 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): Country
# dbl (12): GDP PC, GDP US bill, GDP Growth %, Services % GDP, Creat Ind % GDP...
#
# ...

# %%
#Buscando correlaciones con pairs en dataset proyecto
View(orangeec)
pairs(orangeec[,2:6])
pairs(orangeec[,5:10])
# Out:
#    Country     GDP PC GDP US bill GDP Growth % Services % GDP Creat Ind % GDP
# 1  Argentina   20900      637.7   2.9          60.9           3.8
# 2  Belize       8300     1854.0   0.8          62.2            NA
# 3  Bolivia      7500       37.1   4.2          50.0            NA
# 4  Brazil      15600  2055000.0   1.0          72.8           2.6
# 5  Chile       24500      277.0   1.5          64.3           2.2
# 6  Colombia    14500      309.2   1.8          61.4           3.3
# 7  Costa Rica  16900       58.1   3.2          73.5           2.0
# 8  Ecuador     11500      102.3   2.7          56.9           2.0
# 9  El Salvador  8900       28.0   2.4          64.9            NA
# 10 Guatemala    8100       75.7   2.8          63.2            NA
# 11 Honduras     5600       22.9   4.8          57.8            NA
# 12 Mexico      19900  1149000.0   2.0          64.0           7.4
# 13 Nicaragua    5800       13.7   4.9          50.8            NA
# ...

# %%
New_data2 <- subset(orangeec, select = c(5,6,10,11,12,13))
New_data2
pairs(New_data2)
# Out:
#    Services % GDP Creat Ind % GDP Internet penetration % population Median age
# 1  60.9           3.8             93.1                              31.7
# 2  62.2            NA             52.3                              22.7
# 3  50.0            NA             78.6                              24.3
# 4  72.8           2.6             70.7                              32.0
# 5  64.3           2.2             77.5                              34.4
# 6  61.4           3.3             63.2                              30.0
# 7  73.5           2.0             86.7                              31.3
# 8  56.9           2.0             79.9                              27.7
# 9  64.9            NA             57.7                              27.1
# 10 63.2            NA             42.1                              22.1
# 11 57.8            NA             38.2                              23.0
# 12 64.0           7.4             65.0                              28.3
# ...

# %%
# Seleccionar las columnas numéricas relevantes del dataset orangeec
numerical_columns <- orangeec[, c("GDP PC", "Internet penetration % population", 
                                  "Creat Ind % GDP", "Education invest % GDP", 
                                  "Unemployment")]
numerical_columns
# Out:
#    GDP PC Internet penetration % population Creat Ind % GDP
# 1  20900  93.1                              3.8
# 2   8300  52.3                               NA
# 3   7500  78.6                               NA
# 4  15600  70.7                              2.6
# 5  24500  77.5                              2.2
# 6  14500  63.2                              3.3
# 7  16900  86.7                              2.0
# 8  11500  79.9                              2.0
# 9   8900  57.7                               NA
# 10  8100  42.1                               NA
# 11  5600  38.2                               NA
# 12 19900  65.0                              7.4
# 13  5800  43.0                               NA
# 14 25400  69.7                              6.3
# 15  9800  89.6                              4.1
# 16 13300  67.6                              1.5
# 17 22400  88.2                              1.0
#    Education invest % GDP Unemployment
# 1  5.9                     8.1
# ...

# %%
# Generar la matriz de gráficos de dispersión
pairs(numerical_columns, 
      main = "Matriz de Gráficos de Dispersión - Dataset Orangeec",
      col = "darkgreen", pch = 19)
# Out:
# plot without title

# %%
# Calcular la matriz de correlación numérica
correlation_matrix <- cor(numerical_columns, use = "complete.obs")

# Imprimir la matriz de correlación
print(correlation_matrix)
# Out:
#                                         GDP PC
# GDP PC                             1.000000000
# Internet penetration % population -0.002780908
# Creat Ind % GDP                    0.260632769
# Education invest % GDP            -0.186462328
# Unemployment                      -0.127879089
#                                   Internet penetration % population
# GDP PC                                                 -0.002780908
# Internet penetration % population                       1.000000000
# Creat Ind % GDP                                        -0.343516446
# Education invest % GDP                                  0.435571370
# Unemployment                                           -0.025345377
#                                   Creat Ind % GDP Education invest % GDP
# GDP PC                                  0.2606328             -0.1864623
# Internet penetration % population      -0.3435164              0.4355714
# ...

# %%
pairs(orangeec[,5:10])
cor(orangeec[,5:10], use = 'complete.obs')
# Out:
#                                   Services % GDP Creat Ind % GDP Inflation
# Services % GDP                     1.0000000      0.2201699      -0.1985176
# Creat Ind % GDP                    0.2201699      1.0000000       0.1189514
# Inflation                         -0.1985176      0.1189514       1.0000000
# Unemployment                       0.1770322     -0.4188541       0.1418000
# % pop below poverty line          -0.2534107      0.7072581       0.1702550
# Internet penetration % population -0.1453060     -0.3435164       0.4459355
#                                   Unemployment % pop below poverty line
# Services % GDP                     0.17703222  -0.2534107
# Creat Ind % GDP                   -0.41885405   0.7072581
# Inflation                          0.14179995   0.1702550
# Unemployment                       1.00000000  -0.5693572
# % pop below poverty line          -0.56935718   1.0000000
# Internet penetration % population -0.02534538  -0.3080290
# ...

# %%
cor(New_data2)
cor(New_data2, use = 'complete.obs')
# Out:
#                                   Services % GDP Creat Ind % GDP
# Services % GDP                     1.0000000     NA
# Creat Ind % GDP                           NA      1
# Internet penetration % population  0.1721324     NA
# Median age                         0.4639534     NA
# % pop 25-54                        0.3558270     NA
# Education invest % GDP            -0.1822658     NA
#                                   Internet penetration % population Median age
# Services % GDP                    0.1721324                          0.46395341
# Creat Ind % GDP                          NA                                  NA
# Internet penetration % population 1.0000000                          0.71592074
# Median age                        0.7159207                          1.00000000
# % pop 25-54                       0.5148357                          0.76571511
# Education invest % GDP            0.2472698                         -0.05448538
# ...

# %%
# Seleccionar las columnas numéricas de interés en el dataset orangeec
numerical_columns <- orangeec[, c("GDP PC", "Internet penetration % population", 
                                  "Creat Ind % GDP", "Education invest % GDP", 
                                  "Unemployment")]

# %%
# Calcular la matriz de correlación
correlation_matrix <- cor(numerical_columns, use = "complete.obs")

# %%
# Imprimir la matriz de correlación
print(correlation_matrix)
# Out:
#                                         GDP PC
# GDP PC                             1.000000000
# Internet penetration % population -0.002780908
# Creat Ind % GDP                    0.260632769
# Education invest % GDP            -0.186462328
# Unemployment                      -0.127879089
#                                   Internet penetration % population
# GDP PC                                                 -0.002780908
# Internet penetration % population                       1.000000000
# Creat Ind % GDP                                        -0.343516446
# Education invest % GDP                                  0.435571370
# Unemployment                                           -0.025345377
#                                   Creat Ind % GDP Education invest % GDP
# GDP PC                                  0.2606328             -0.1864623
# Internet penetration % population      -0.3435164              0.4355714
# ...

# %% [markdown]
# # Clase #28
# # Eliminando los NA's para hacer los cálculos.

# %%
summary(orangeec)
# Out:
#    Country              GDP PC       GDP US bill         GDP Growth %
#  Length:17          Min.   : 5600   Min.   :     13.7   Min.   :0.800
#  Class :character   1st Qu.: 8300   1st Qu.:     37.1   1st Qu.:2.000
#  Mode  :character   Median :13300   Median :     75.7   Median :2.800
#                     Mean   :14053   Mean   : 188693.0   Mean   :2.959
#                     3rd Qu.:19900   3rd Qu.:    309.2   3rd Qu.:4.200
#                     Max.   :25400   Max.   :2055000.0   Max.   :5.400
#
#  Services % GDP  Creat Ind % GDP   Inflation       Unemployment
#  Min.   :50.00   Min.   :1.000   Min.   : 0.400   Min.   : 2.300
#  1st Qu.:56.90   1st Qu.:2.000   1st Qu.: 1.600   1st Qu.: 5.500
#  Median :62.20   Median :2.600   Median : 3.400   Median : 6.700
#  Mean   :62.64   Mean   :3.291   Mean   : 4.365   Mean   : 6.794
#  3rd Qu.:64.90   3rd Qu.:3.950   3rd Qu.: 4.300   3rd Qu.: 8.100
#  Max.   :82.00   Max.   :7.400   Max.   :25.700   Max.   :11.800
# ...

# %%
#Desviación standar
names(orangeec)
sd(orangeec$`Internet penetration % population`)
desv2 <- sd(orangeec$`Internet penetration % population`)
desv2
# Out:
#  [1] "Country"                           "GDP PC"
#  [3] "GDP US bill"                       "GDP Growth %"
#  [5] "Services % GDP"                    "Creat Ind % GDP"
#  [7] "Inflation"                         "Unemployment"
#  [9] "% pop below poverty line"          "Internet penetration % population"
# [11] "Median age"                        "% pop 25-54"
# [13] "Education invest % GDP"
# [1] 17.27419
# [1] 17.27419

# %%
#Promedio
mean(orangeec$`Internet penetration % population`)
prom <- mean(orangeec$`Internet penetration % population`)
prom
# Out:
# [1] 68.41765
# [1] 68.41765

# %%
DesvProm <- (desv2/prom)*100
DesvProm
summary(orangeec)
# Out:
# [1] 25.24816
#    Country              GDP PC       GDP US bill         GDP Growth %
#  Length:17          Min.   : 5600   Min.   :     13.7   Min.   :0.800
#  Class :character   1st Qu.: 8300   1st Qu.:     37.1   1st Qu.:2.000
#  Mode  :character   Median :13300   Median :     75.7   Median :2.800
#                     Mean   :14053   Mean   : 188693.0   Mean   :2.959
#                     3rd Qu.:19900   3rd Qu.:    309.2   3rd Qu.:4.200
#                     Max.   :25400   Max.   :2055000.0   Max.   :5.400
#
#  Services % GDP  Creat Ind % GDP   Inflation       Unemployment
#  Min.   :50.00   Min.   :1.000   Min.   : 0.400   Min.   : 2.300
#  1st Qu.:56.90   1st Qu.:2.000   1st Qu.: 1.600   1st Qu.: 5.500
#  Median :62.20   Median :2.600   Median : 3.400   Median : 6.700
#  Mean   :62.64   Mean   :3.291   Mean   : 4.365   Mean   : 6.794
#  3rd Qu.:64.90   3rd Qu.:3.950   3rd Qu.: 4.300   3rd Qu.: 8.100
#  Max.   :82.00   Max.   :7.400   Max.   :25.700   Max.   :11.800
# ...

# %%
#Removiendo valores NA
mean(orangeec$`Creat Ind % GDP`)
mean(orangeec$`Creat Ind % GDP`, na.rm = TRUE)
prom2 <- mean(orangeec$`Creat Ind % GDP`, na.rm = TRUE)
# Out:
# [1] NA
# [1] 3.290909

# %%
#Desviasión estandar
sd(orangeec$`Creat Ind % GDP`)
sd(orangeec$`Creat Ind % GDP`, na.rm = TRUE)
Desv <- sd(orangeec$`Creat Ind % GDP`, na.rm = TRUE)
# Out:
# [1] NA
# [1] 2.007712

# %%
#Coeficiente
coefC <- (Desv/prom2)*100
coef
# Out:
# function (object, ...)
# UseMethod("coef")
# <bytecode: 0x152f4f80>
# <environment: namespace:stats>

# %%
# Eliminando filas con NA en todo el dataset
orangeec_clean <- na.omit(orangeec)

# %%
# Calculando la correlación en el dataset limpio
cor_matrix <- cor(orangeec_clean, use = "complete.obs")
# Out:
# Error in cor(orangeec_clean, use = "complete.obs"): 'x' must be numeric
# Traceback:
#
# 1. cor(orangeec_clean, use = "complete.obs")
# 2. stop("'x' must be numeric")

# %%
# Imprimiendo la matriz de correlación
print(cor_matrix)
# Out:
# Error in eval(expr, envir, enclos): object 'cor_matrix' not found
# Traceback:
#
# 1. print(cor_matrix)
